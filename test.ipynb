# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2 

DATADIR = "./BangladeshiCrops/Crop___Disease/Rice/"
CATEGORIES = ["Rice___Neck_Blast", "Rice___Leaf_Blast", "Rice___Healthy", "Rice___Brown_Spot"]

for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        print(os.stat(os.path.join(path,img)))
        img_array = cv2.imread(os.path.join(path,img)
        plt.imshow(img_array, cmap = "gray")
        plt.show()
        break
    break
# Out:
# os.stat_result(st_mode=33204, st_ino=113068363, st_dev=16777222, st_nlink=1, st_uid=501, st_gid=20, st_size=1476577, st_atime=1667676348, st_mtime=1667676310, st_ctime=1667676310)
